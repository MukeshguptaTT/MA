# %%
input = "Barack Obama went as a prime minister of USA in the year of 2015 . PM MODI is the prime minister of INDIA."
print(input)
# Out:
# Barack Obama went as a prime minister of USA in the year of 2015 . PM MODI is the prime minister of INDIA.

# %%
#(1)lowercase
lowercase = input.lower()
print("LOWERCSE = ", lowercase)

#re
#pip install re
import re
lowercase_re = re.sub('2015', '2025', lowercase)
print("REGULAR EXP1 = ", lowercase_re)
lowercase_re = re.sub('[a-m]', '*', lowercase)
print("REGULAR EXP2 = ", lowercase_re)
lowercase_re = re.sub('\d', '-', lowercase)
print("REGULAR EXP3 = ", lowercase_re)
# Out:
# LOWERCSE =  barack obama went as a prime minister of usa in the year of 2015 . pm modi is the prime minister of india.
# REGULAR EXP1 =  barack obama went as a prime minister of usa in the year of 2025 . pm modi is the prime minister of india.
# REGULAR EXP2 =  **r*** o**** w*nt *s * pr*** **n*st*r o* us* *n t** y**r o* 2015 . p* *o** *s t** pr*** **n*st*r o* *n***.
# REGULAR EXP3 =  barack obama went as a prime minister of usa in the year of ---- . pm modi is the prime minister of india.

# %%
#(2)Tokenization
import nltk
from nltk import word_tokenize, sent_tokenize

word_tokens = word_tokenize(input)
print("WORD TOKENS = ", word_tokens)
print(len(word_tokens))
sent_tokens = sent_tokenize(input)
print("SENT TOKENS = ", sent_tokens)
print(len(sent_tokens))
# Out:
# WORD TOKENS =  ['Barack', 'Obama', 'went', 'as', 'a', 'prime', 'minister', 'of', 'USA', 'in', 'the', 'year', 'of', '2015', '.', 'PM', 'MODI', 'is', 'the', 'prime', 'minister', 'of', 'INDIA', '.']
# 24
# SENT TOKENS =  ['Barack Obama went as a prime minister of USA in the year of 2015 .', 'PM MODI is the prime minister of INDIA.']
# 2

# %%
#(3)stopwords Removal
from nltk.corpus import stopwords
#print(stopwords.fileids())
stopwords = set(stopwords.words('english'))
#print("\n", stopwords)

tokens_stopwords = []
for token in word_tokens:
    if token not in stopwords:
        tokens_stopwords.append(token)
print(' '.join(tokens_stopwords))
# Out:
# Barack Obama went prime minister USA year 2015 . PM MODI prime minister INDIA .

# %%
#Stemmer
stemming = []
from nltk import PorterStemmer
for word in tokens_stopwords:
    stemming.append(PorterStemmer().stem(word))
print(stemming)
# Out:
# ['barack', 'obama', 'went', 'prime', 'minist', 'usa', 'year', '2015', '.', 'pm', 'modi', 'prime', 'minist', 'india', '.']

# %%
#Lemmatizer
from nltk import WordNetLemmatizer
lma = []
for word in tokens_stopwords:
    lma.append(WordNetLemmatizer().lemmatize(word))
print(lma)
# Out:
# ['Barack', 'Obama', 'went', 'prime', 'minister', 'USA', 'year', '2015', '.', 'PM', 'MODI', 'prime', 'minister', 'INDIA', '.']

# %%
#POS Tags
from nltk import pos_tag
print(pos_tag(word_tokens))
# Out:
# [('Barack', 'NNP'), ('Obama', 'NNP'), ('went', 'VBD'), ('as', 'IN'), ('a', 'DT'), ('prime', 'JJ'), ('minister', 'NN'), ('of', 'IN'), ('USA', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('year', 'NN'), ('of', 'IN'), ('2015', 'CD'), ('.', '.'), ('PM', 'NNP'), ('MODI', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('prime', 'JJ'), ('minister', 'NN'), ('of', 'IN'), ('INDIA', 'NNP'), ('.', '.')]

# %% [markdown]
# # NER

# %%
pip install spacy
# Out:
# Collecting spacyNote: you may need to restart the kernel to use updated packages.
#   Using cached spacy-3.8.2.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   Using cached spacy-3.7.5-cp38-cp38-win_amd64.whl (12.5 MB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Collecting typer<1.0.0,>=0.3.0
#   Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting weasel<0.5.0,>=0.1.0
#   Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\users\denge\anaconda3\lib\site-packages (from spacy) (4.59.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\users\denge\anaconda3\lib\site-packages (from spacy) (2.25.1)
# Collecting thinc<8.3.0,>=8.2.2
#   Using cached thinc-8.2.5.tar.gz (193 kB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   Using cached thinc-8.2.4-cp38-cp38-win_amd64.whl (1.5 MB)
# Requirement already satisfied: packaging>=20.0 in d:\users\denge\anaconda3\lib\site-packages (from spacy) (20.9)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy>=1.15.0 in d:\users\denge\anaconda3\lib\site-packages (from spacy) (1.22.4)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.11.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: setuptools in d:\users\denge\anaconda3\lib\site-packages (from spacy) (52.0.0.post20210125)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.10.tar.gz (15 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached preshed-3.0.9-cp38-cp38-win_amd64.whl (122 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.4.1-py3-none-any.whl (182 kB)
#
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.13.tar.gz (13 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Requirement already satisfied: jinja2 in d:\users\denge\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.8-cp38-cp38-win_amd64.whl (483 kB)
# Collecting language-data>=1.2
#   Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Collecting marisa-trie>=1.1.0
#   Using cached marisa_trie-1.2.1-cp38-cp38-win_amd64.whl (152 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\users\denge\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-extensions>=4.12.2
#   Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Collecting pydantic-core==2.27.2
#   Using cached pydantic_core-2.27.2-cp38-cp38-win_amd64.whl (2.0 MB)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\denge\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\users\denge\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\denge\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in d:\users\denge\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-8t1alz_v\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=8.3.0,<8.4.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#        cwd: None
#   Complete output (366 lines):
#   Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#   Collecting cython<3.0,>=0.25
#     Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached cymem-2.0.11.tar.gz (10 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting preshed<3.1.0,>=3.0.2
#     Using cached preshed-3.0.10.tar.gz (15 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-qpg74gy1\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0'
#          cwd: None
#     Complete output (73 lines):
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython>=0.28
#       Using cached cython-3.1.2-cp38-cp38-win_amd64.whl (2.7 MB)
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting murmurhash<1.1.0,>=0.28.0
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Building wheels for collected packages: cymem, murmurhash
#       Building wheel for cymem (PEP 517): started
#       Building wheel for cymem (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmphqtflcl1'
#            cwd: C:\Users\denge\AppData\Local\Temp\pip-install-k6vecsht\cymem_826395fe2a424d2a93f533befb18399b
#       Complete output (15 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\cymem
#       copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#       creating build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.11-cp38-cp38-win_amd64.whl (6.6 MB)
# Collecting shellingham>=1.3.0
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0
#   Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Collecting click>=8.0.0
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Requirement already satisfied: colorama in d:\users\denge\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0.0,>=0.3.0->spacy) (0.4.4)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached pygments-2.19.2-py3-none-any.whl (1.2 MB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting smart-open<8.0.0,>=5.2.1
#   Using cached smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Using cached cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Requirement already satisfied: wrapt in d:\users\denge\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.12.1)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\users\denge\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Building wheels for collected packages: cymem, murmurhash
#   Building wheel for cymem (PEP 517): started
#   Building wheel for cymem (PEP 517): finished with status 'error'
#   Building wheel for murmurhash (PEP 517): started
#   Building wheel for murmurhash (PEP 517): finished with status 'error'
# Failed to build cymem murmurhash
#       copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#       running build_ext
#       building 'cymem.cymem' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for cymem
#       Building wheel for murmurhash (PEP 517): started
#       Building wheel for murmurhash (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmpjzpg_en5'
#            cwd: C:\Users\denge\AppData\Local\Temp\pip-install-k6vecsht\murmurhash_044c20daada14f298b8f24718fb883ea
#       Complete output (19 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       running build_ext
#       building 'murmurhash.mrmr' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for murmurhash
#     Failed to build cymem murmurhash
#     ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6). Command errored out with exit status 1: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-qpg74gy1\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' Check the logs for full command output.
#     Using cached preshed-3.0.9-cp38-cp38-win_amd64.whl (122 kB)
#   Collecting murmurhash<1.1.0,>=0.28.0
#     Using cached murmurhash-1.0.13.tar.gz (13 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting thinc<8.4.0,>=8.3.0
#     Using cached thinc-8.3.2.tar.gz (193 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 2:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-mb06csaq\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#          cwd: None
#     Complete output (77 lines):
#     Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython<3.0,>=0.25
#       Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#     Collecting murmurhash<1.1.0,>=1.0.2
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting preshed<3.1.0,>=3.0.2
#       Using cached preshed-3.0.10.tar.gz (15 kB)
#     ERROR: Exception:
#     Traceback (most recent call last):
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 171, in _merge_into_criterion
#         crit = self.state.criteria[name]
#     KeyError: 'preshed'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#         status = self.run(options, args)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#         return func(self, options, args)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#         requirement_set = resolver.resolve(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 121, in resolve
#         self._result = resolver.resolve(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 453, in resolve
#         state = resolution.resolve(requirements, max_rounds=max_rounds)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 318, in resolve
#         name, crit = self._merge_into_criterion(r, parent=None)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _merge_into_criterion
#         crit = Criterion.from_requirement(self._p, requirement, parent)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 82, in from_requirement
#         if not cands:
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 124, in __bool__
#         return bool(self._sequence)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#         return any(self)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 38, in _iter_built
#         candidate = func()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#         self._link_candidate_cache[link] = LinkCandidate(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#         super().__init__(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#         self.dist = self._prepare()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#         dist = self._prepare_distribution()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#         return self._factory.preparer.prepare_linked_requirement(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#         return self._prepare_linked_requirement(req, parallel_builds)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 500, in _prepare_linked_requirement
#         dist = _get_prepared_distribution(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 65, in _get_prepared_distribution
#         with req_tracker.track(req):
#       File "D:\Users\denge\anaconda3\lib\contextlib.py", line 113, in __enter__
#         return next(self.gen)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\req\req_tracker.py", line 144, in track
#         self.add(req)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\req\req_tracker.py", line 110, in add
#         raise LookupError(message)
#     LookupError: https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6) is already being built: preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/8a/9f/b2193b69dd112a46800182e897cda2fc9c497dfdd9352a0c5ba9252cf5f0/thinc-8.3.2.tar.gz#sha256=3e8ef69eac89a601e11d47fc9e43d26ffe7ef682dcf667c94ff35ff690549aeb (from https://pypi.org/simple/thinc/) (requires-python:>=3.6). Command errored out with exit status 2: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-mb06csaq\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#     Using cached thinc-8.3.1.tar.gz (193 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 2:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-can_7ss_\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#          cwd: None
#     Complete output (77 lines):
#     Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython<3.0,>=0.25
#       Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#     Collecting murmurhash<1.1.0,>=1.0.2
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting preshed<3.1.0,>=3.0.2
#       Using cached preshed-3.0.10.tar.gz (15 kB)
#     ERROR: Exception:
#     Traceback (most recent call last):
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 171, in _merge_into_criterion
#         crit = self.state.criteria[name]
#     KeyError: 'preshed'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#         status = self.run(options, args)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#         return func(self, options, args)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#         requirement_set = resolver.resolve(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 121, in resolve
#         self._result = resolver.resolve(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 453, in resolve
#         state = resolution.resolve(requirements, max_rounds=max_rounds)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 318, in resolve
#         name, crit = self._merge_into_criterion(r, parent=None)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _merge_into_criterion
#         crit = Criterion.from_requirement(self._p, requirement, parent)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 82, in from_requirement
#         if not cands:
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 124, in __bool__
#         return bool(self._sequence)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#         return any(self)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 38, in _iter_built
#         candidate = func()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#         self._link_candidate_cache[link] = LinkCandidate(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#         super().__init__(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#         self.dist = self._prepare()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#         dist = self._prepare_distribution()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#         return self._factory.preparer.prepare_linked_requirement(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#         return self._prepare_linked_requirement(req, parallel_builds)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 500, in _prepare_linked_requirement
#         dist = _get_prepared_distribution(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 65, in _get_prepared_distribution
#         with req_tracker.track(req):
#       File "D:\Users\denge\anaconda3\lib\contextlib.py", line 113, in __enter__
#         return next(self.gen)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\req\req_tracker.py", line 144, in track
#         self.add(req)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\req\req_tracker.py", line 110, in add
#         raise LookupError(message)
#     LookupError: https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6) is already being built: preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/ea/60/b7d645d621a47d649975b53c13cdf3e66b456a24727ccd34794f1014f45c/thinc-8.3.1.tar.gz#sha256=44e747bbf93e981dfded7d432b68ef1ba75b28ef46fc51f185477970743b36e9 (from https://pypi.org/simple/thinc/) (requires-python:>=3.6). Command errored out with exit status 2: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-can_7ss_\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#     Using cached thinc-8.3.0.tar.gz (193 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 2:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-h4z5cda9\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#          cwd: None
#     Complete output (77 lines):
#     Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython<3.0,>=0.25
#       Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#     Collecting murmurhash<1.1.0,>=1.0.2
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting preshed<3.1.0,>=3.0.2
#       Using cached preshed-3.0.10.tar.gz (15 kB)
#     ERROR: Exception:
#     Traceback (most recent call last):
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 171, in _merge_into_criterion
#         crit = self.state.criteria[name]
#     KeyError: 'preshed'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#         status = self.run(options, args)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#         return func(self, options, args)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#         requirement_set = resolver.resolve(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 121, in resolve
#         self._result = resolver.resolve(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 453, in resolve
#         state = resolution.resolve(requirements, max_rounds=max_rounds)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 318, in resolve
#         name, crit = self._merge_into_criterion(r, parent=None)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _merge_into_criterion
#         crit = Criterion.from_requirement(self._p, requirement, parent)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 82, in from_requirement
#         if not cands:
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 124, in __bool__
#         return bool(self._sequence)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#         return any(self)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 38, in _iter_built
#         candidate = func()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#         self._link_candidate_cache[link] = LinkCandidate(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#         super().__init__(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#         self.dist = self._prepare()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#         dist = self._prepare_distribution()
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#         return self._factory.preparer.prepare_linked_requirement(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#         return self._prepare_linked_requirement(req, parallel_builds)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 500, in _prepare_linked_requirement
#         dist = _get_prepared_distribution(
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 65, in _get_prepared_distribution
#         with req_tracker.track(req):
#       File "D:\Users\denge\anaconda3\lib\contextlib.py", line 113, in __enter__
#         return next(self.gen)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\req\req_tracker.py", line 144, in track
#         self.add(req)
#       File "D:\Users\denge\anaconda3\lib\site-packages\pip\_internal\req\req_tracker.py", line 110, in add
#         raise LookupError(message)
#     LookupError: https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6) is already being built: preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/15/0a/250f7fa34632616bb4fc37decbc46ed09243bade708968dc869d8a4c144b/thinc-8.3.0.tar.gz#sha256=eb3bed54f5c00ec9addaaa208c51ccfa059483d73140cd515aa33373715c6e59 (from https://pypi.org/simple/thinc/) (requires-python:>=3.6). Command errored out with exit status 2: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-h4z5cda9\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#   ERROR: Could not find a version that satisfies the requirement thinc<8.4.0,>=8.3.0
#   ERROR: No matching distribution found for thinc<8.4.0,>=8.3.0
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/07/53/536941af8fbb5cb10a778f0dbd2a17b0f13e7ebfc11e67b154be60508fdf/spacy-3.8.2.tar.gz#sha256=4b37ebd25ada4059b0dc9e0893e70dde5df83485329a068ef04580e70892a65d (from https://pypi.org/simple/spacy/) (requires-python:>=3.7). Command errored out with exit status 1: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-8t1alz_v\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=8.3.0,<8.4.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-ithntl5q\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=0.7.8,<0.8.0' 'numpy>=1.15.0,<2.0.0; python_version < '"'"'3.9'"'"'' 'numpy>=1.25.0,<2.0.0; python_version >= '"'"'3.9'"'"''
#        cwd: None
#   Complete output (162 lines):
#   Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#   Collecting cython<3.0,>=0.25
#     Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#   Collecting murmurhash<1.1.0,>=1.0.2
#     Using cached murmurhash-1.0.13.tar.gz (13 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached cymem-2.0.11.tar.gz (10 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting preshed<3.1.0,>=3.0.2
#     Using cached preshed-3.0.10.tar.gz (15 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-7ots6m9e\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0'
#          cwd: None
#     Complete output (73 lines):
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython>=0.28
#       Using cached cython-3.1.2-cp38-cp38-win_amd64.whl (2.7 MB)
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting murmurhash<1.1.0,>=0.28.0
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Building wheels for collected packages: cymem, murmurhash
#       Building wheel for cymem (PEP 517): started
#       Building wheel for cymem (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmpcpe7vy01'
#            cwd: C:\Users\denge\AppData\Local\Temp\pip-install-pxcir2l6\cymem_2e7047b64de447a68db22f0fc536dddb
#       Complete output (15 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\cymem
#       copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#       creating build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#       running build_ext
#       building 'cymem.cymem' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for cymem
#       Building wheel for murmurhash (PEP 517): started
#       Building wheel for murmurhash (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmparn9nsqx'
#            cwd: C:\Users\denge\AppData\Local\Temp\pip-install-pxcir2l6\murmurhash_d1dc14a42f9f4e8cb9cbc00d1050e5e8
#       Complete output (19 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       running build_ext
#       building 'murmurhash.mrmr' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for murmurhash
#     Failed to build cymem murmurhash
#     ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6). Command errored out with exit status 1: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-7ots6m9e\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' Check the logs for full command output.
#     Using cached preshed-3.0.9-cp38-cp38-win_amd64.whl (122 kB)
#   Collecting blis<0.8.0,>=0.7.8
#     Using cached blis-0.7.11-cp38-cp38-win_amd64.whl (6.6 MB)
#   Collecting numpy<2.0.0,>=1.15.0
#     Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#   Building wheels for collected packages: cymem, murmurhash
#     Building wheel for cymem (PEP 517): started
#     Building wheel for cymem (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmp9kyc4w4m'
#          cwd: C:\Users\denge\AppData\Local\Temp\pip-install-h4xowbs3\cymem_206f1f78b612446d880cb008b0709644
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build\lib.win-amd64-cpython-38\cymem
#     copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#     creating build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#     running build_ext
#     building 'cymem.cymem' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for cymem
#     Building wheel for murmurhash (PEP 517): started
#     Building wheel for murmurhash (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmp98e8xq_z'
#          cwd: C:\Users\denge\AppData\Local\Temp\pip-install-h4xowbs3\murmurhash_1d0dee0dbd294e769fbaa51230a2ded2
#     Complete output (19 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     running build_ext
#     building 'murmurhash.mrmr' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for murmurhash
#   Failed to build cymem murmurhash
#   ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3b/2a/0e2e961e6152bedecca70e6833f6e827ee621efcee7496643242b506d54f/thinc-8.2.5.tar.gz#sha256=c2963791c934cc7fbd8f9b942d571cac79892ad11630bfca690a868c32752b75 (from https://pypi.org/simple/thinc/) (requires-python:>=3.6). Command errored out with exit status 1: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-ithntl5q\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=0.7.8,<0.8.0' 'numpy>=1.15.0,<2.0.0; python_version < '"'"'3.9'"'"'' 'numpy>=1.25.0,<2.0.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-42f2fkbd\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0'
#        cwd: None
#   Complete output (73 lines):
#   Collecting setuptools
#     Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#   Collecting cython>=0.28
#     Using cached cython-3.1.2-cp38-cp38-win_amd64.whl (2.7 MB)
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached cymem-2.0.11.tar.gz (10 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting murmurhash<1.1.0,>=0.28.0
#     Using cached murmurhash-1.0.13.tar.gz (13 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: cymem, murmurhash
#     Building wheel for cymem (PEP 517): started
#     Building wheel for cymem (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmpi8wfewub'
#          cwd: C:\Users\denge\AppData\Local\Temp\pip-install-qg8iazdm\cymem_b2a9987c12de4fd782d9b90833d4af68
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build\lib.win-amd64-cpython-38\cymem
#     copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#     creating build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#     running build_ext
#     building 'cymem.cymem' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for cymem
#     Building wheel for murmurhash (PEP 517): started
#     Building wheel for murmurhash (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmp8jam9tiy'
#          cwd: C:\Users\denge\AppData\Local\Temp\pip-install-qg8iazdm\murmurhash_de400635f24c42218089a03f0fc84122
#     Complete output (19 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     running build_ext
#     building 'murmurhash.mrmr' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for murmurhash
#   Failed to build cymem murmurhash
#   ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6). Command errored out with exit status 1: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip' install --ignore-installed --no-user --prefix 'C:\Users\denge\AppData\Local\Temp\pip-build-env-42f2fkbd\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmp2gihke4t'
#        cwd: C:\Users\denge\AppData\Local\Temp\pip-install-n9ijo9c9\cymem_ab82588c0f954d79959bf03b2f5079d1
#   Complete output (15 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-38\cymem
#   copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#   copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#   creating build\lib.win-amd64-cpython-38\cymem\tests
#   copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#   copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#   copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#   copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#   copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#   running build_ext
#   building 'cymem.cymem' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for cymem
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Users\denge\anaconda3\python.exe' 'D:\Users\denge\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\denge\AppData\Local\Temp\tmpqvlmxwa1'
#        cwd: C:\Users\denge\AppData\Local\Temp\pip-install-n9ijo9c9\murmurhash_15381034017a42c78ebbccca44baad26
#   Complete output (19 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#   creating build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#   creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#   copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#   copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#   running build_ext
#   building 'murmurhash.mrmr' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for murmurhash
# ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly

# %%
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk, sent_tokenize

input = "Barack Obama went as a prime minister of USA in the year of 2015 . PM MODI is the prime minister of INDIA."
ner = ne_chunk(pos_tag(word_tokenize(input)))
# print(ner)

from nltk.tree import Tree
named_entity = []
for subtree in ner:
    if isinstance(subtree, Tree):
        entity = "".join([token for token, pos in subtree.leaves()])
        named_entity.append(entity)
print(named_entity)

# %%
#pip install spacy
import spacy
nlp = spacy.load("en_core_web_sm")

text = "Barack Obama went as a prime minister of USA in the year of 2015 . PM MODI is the prime minister of INDIA."
doc = nlp(text)
named_entity = []
for ent in doc.ents:
    named_entity.append(ent.text)
print(named_entity)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-54d586c558e1> in <module>
#       1 #pip install spacy
# ----> 2 import spacy
#       3 nlp = spacy.load("en_core_web_sm")
#       4
#       5 text = "Barack Obama went as a prime minister of USA in the year of 2015 . PM MODI is the prime minister of INDIA."
#
# ModuleNotFoundError: No module named 'spacy'
